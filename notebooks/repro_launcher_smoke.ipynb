# %% [markdown]
# # Paper Reproduction Launcher (Smoke Run)
#
# This Colab-friendly notebook drives the existing CLI scripts in `summarization/` to run very small LED and Llama jobs. It uses the `train_last_100.json` / `valid_last_100.json` splits so we can exercise the full code paths quickly before launching the long runs described in the paper.

# %%
# @title Sync the local repository from Google Drive (no git clone)
from pathlib import Path
import os
import importlib.util

COLAB = importlib.util.find_spec("google.colab") is not None
if COLAB:
    from google.colab import drive  # type: ignore
    drive.mount('/content/drive', force_remount=True)
    REPO_IN_DRIVE = Path('/content/drive/Othercomputers/My Mac/patient_summaries_with_llms/')  # @param {type:"string"}
    if not REPO_IN_DRIVE.exists():
        raise FileNotFoundError(f"Upload/sync the local repo to {REPO_IN_DRIVE} first.")
    TARGET_DIR = Path('/content/patient_summaries_with_llms')
    TARGET_DIR.mkdir(parents=True, exist_ok=True)
    os.system(f"rsync --progress -a --delete '{REPO_IN_DRIVE}/summarization' '{TARGET_DIR}/'")
    os.system(f"rsync --progress -a --delete '{REPO_IN_DRIVE}/data' '{TARGET_DIR}/'")
    # %cd /content/patient_summaries_with_llms
else:
    print("Running outside Colab; using the current working directory.")
    TARGET_DIR = Path.cwd()
# Out:
# Mounted at /content/drive
# /content/patient_summaries_with_llms

# %%
# @title Install base dependencies shared by LED + evaluation
# %pip install -q numpy==1.26.4
# %pip install -q torch==2.2.0+cu121 torchvision==0.20.1+cu121 torchaudio==2.2.1+cu121 --extra-index-url https://download.pytorch.org/whl/cu121
# %pip install -q torch==2.3.1+cu121 torchvision==0.18.1+cu121 torchaudio==2.3.1+cu121 --extra-index-url https://download.pytorch.org/whl/cu121
# %pip install -q transformers==4.40.1 datasets==2.18.0 accelerate==0.28.0 evaluate==0.4.1 rouge-score==0.1.2 sacrebleu==2.4.0 sentencepiece==0.1.99 wandb==0.16.6 fsspec==2023.10.0 gcsfs==2023.10.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.9/780.9 MB 860.6 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 66.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 85.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 4.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 5.1.2 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.40.1 which is incompatible.

# %%
# @title Install dependencies used by both scripts%pip install -q transformers==4.39.3 datasets==2.18.0 accelerate==0.28.0 evaluate rouge-score sacrebleu sentencepiece trl==0.7.10 peft==0.10.0 wandb

# %% [markdown]
# ## LED smoke run (`summarization/run_summarization.py`)
#
# Trains/evaluates `allenai/led-base-16384` on the last 100 training examples for one epoch to ensure that tokenization, dataloading, and Trainer hooks work.

# %%
# @title LED-base on train_last_100 / valid_last_100
import os
from pathlib import Path

os.environ["WANDB_MODE"] = "offline"
DATA_DIR = Path("data/ann-pt-summ/1.0.1/mimic-iv-note-ext-di-bhc/dataset")
LED_OUTPUT_DIR = Path("data/led_4000_600_chars")

assert DATA_DIR.exists(), f"Missing dataset folder: {DATA_DIR}"

    # --do_train --do_eval --do_predict \
# !python summarization/run_summarization.py \
    --model_name_or_path allenai/led-base-16384 \
    --train_file {DATA_DIR / 'train_last_100.json'} \
    --validation_file {DATA_DIR / 'valid_last_100.json'} \
    --test_file {DATA_DIR / 'test_last_100.json'} \
    --text_column text \
    --summary_column summary \
    --output_dir /content/led_last100_smoke \
    --do_predict \
    --per_device_train_batch_size 1 \
    --per_device_eval_batch_size 1 \
    --gradient_accumulation_steps 1 \
    --num_train_epochs 1 \
    --max_source_length 2048 \
    --max_target_length 256 \
    --predict_with_generate \
    --logging_steps 10 \
    --save_total_limit 1 \
    --report_to none
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipython-input-1478925582.py in <cell line: 0>()
#       5 os.environ["WANDB_MODE"] = "offline"
#       6 DATA_DIR = Path("data/ann-pt-summ/1.0.1/mimic-iv-note-ext-di-bhc/dataset")
# ----> 7 assert DATA_DIR.exists(), f"Missing dataset folder: {DATA_DIR}"
#       8
#       9 get_ipython().system("python summarization/run_summarization.py      --model_name_or_path allenai/led-base-16384      --train_file {DATA_DIR / 'train_last_100.json'}      --validation_file {DATA_DIR / 'valid_last_100.json'}      --test_file {DATA_DIR / 'test_last_100.json'}      --text_column text      --summary_column summary      --output_dir /content/led_last100_smoke      --do_train --do_eval --do_predict      --per_device_train_batch_size 1      --per_device_eval_batch_size 1      --gradient_accumulation_steps 1      --num_train_epochs 1      --max_source_length 2048      --max_target_length 256      --predict_with_generate      --logging_steps 10      --save_total_limit 1      --report_to none")
#
# AssertionError: Missing dataset folder: data/ann-pt-summ/1.0.1/mimic-iv-note-ext-di-bhc/dataset

# %% [markdown]
# ## Llama LoRA smoke run (`summarization/fine_tune_llama.py`)
#
# Runs a tiny LoRA training job on the same dataset subset (100 examples). This assumes you already have access to `meta-llama/Llama-2-7b-hf` and a GPU runtime; set `HF_TOKEN` in the environment if needed.

# %%
# @title (Optional) Install Llama-specific dependencies
# %pip install -q peft==0.10.0 trl==0.7.10

# %%
# @title Configure HF token and output directories
import os
from pathlib import Path

HF_TOKEN = ""  # @param {"type": "string"}
if HF_TOKEN:
    os.environ["HF_TOKEN"] = HF_TOKEN
os.environ["WANDB_MODE"] = "offline"

LLAMA_OUTPUT = Path("/content/llama_last100_smoke")
LLAMA_OUTPUT.mkdir(parents=True, exist_ok=True)
DATA_DIR = Path("data/ann-pt-summ/1.0.1/mimic-iv-note-ext-di-bhc/dataset")
assert DATA_DIR.exists(), f"Missing dataset folder: {DATA_DIR}"

# %%
# @title Llama 2 7B LoRA fine-tuning on 100-example subset
# !python summarization/fine_tune_llama.py \
    --model_name_or_path meta-llama/Llama-2-7b-hf \
    --data_path {DATA_DIR} \
    --output_path {LLAMA_OUTPUT} \
    --num_train_examples 100 \
    --num_val_examples 100 \
    --evaluation_model_path data/llama_4000_600_chars/best_val_loss \
    --num_test_examples 100 \
    --max_steps 5 \
    --save_and_logging_steps 5 \
    --batch_size 1 \
    --gradient_accumulation_steps 1 \
    --lora_rank 4 \
    --lora_alpha 16 \
    --lora_dropout 0.1 \
    --num_target_modules 2 \
    --learning_rate 5e-5
