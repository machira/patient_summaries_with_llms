# %% [markdown]
# # Paper Reproduction Launcher (Smoke Run)
#
# This Colab-friendly notebook drives the existing CLI scripts in `summarization/` to run very small LED and Llama jobs. It uses the `train_last_100.json` / `valid_last_100.json` splits so we can exercise the full code paths quickly before launching the long runs described in the paper.

# %%
# @title Sync the local repository from Google Drive (no git clone)
from pathlib import Path
import os
import importlib.util

COLAB = importlib.util.find_spec("google.colab") is not None
if COLAB:
    from google.colab import drive  # type: ignore
    drive.mount('/content/drive', force_remount=True)
    REPO_IN_DRIVE = Path('/content/drive/Othercomputers/My Mac/patient_summaries_with_llms/data/')  # @param {type:"string"}
    if not REPO_IN_DRIVE.exists():
        raise FileNotFoundError(f"Upload/sync the local repo to {REPO_IN_DRIVE} first.")
    TARGET_DIR = Path('/content/patient_summaries_with_llms')
    TARGET_DIR.mkdir(parents=True, exist_ok=True)
    os.system(f"rsync --progress -a --delete '{REPO_IN_DRIVE}/summarization' '{TARGET_DIR}/'")
    os.system(f"rsync --progress -a --delete '{REPO_IN_DRIVE}/data' '{TARGET_DIR}/'")
    os.system(f"rsync --progress -a --delete '{REPO_IN_DRIVE}/requirements.txt' '{TARGET_DIR}/'")
    os.system(f"rsync --progress -a --delete '{REPO_IN_DRIVE}/requirements-llama.txt' '{TARGET_DIR}/'")
    # %cd /content/patient_summaries_with_llms
else:
    print("Running outside Colab; using the current working directory.")
    TARGET_DIR = Path.cwd()
# Out:
# Mounted at /content/drive
# /content/patient_summaries_with_llms

# %%
# @title Install base dependencies shared by LED + evaluation
# %pip install -q -r requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement torch==2.3.1+cu121 (from versions: 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1)
# ERROR: No matching distribution found for torch==2.3.1+cu121
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
# @title more dependencies
# %pip install bert bert_score sacremoses
# Out:
# Requirement already satisfied: bert in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (2.2.0)
# Requirement already satisfied: bert_score in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (0.3.13)
# Requirement already satisfied: sacremoses in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (0.1.1)
# Requirement already satisfied: erlastic in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from bert) (2.0.0)
# Requirement already satisfied: torch>=1.0.0 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from bert_score) (2.6.0)
# Requirement already satisfied: pandas>=1.0.1 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from bert_score) (2.3.3)
# Requirement already satisfied: transformers>=3.0.0 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from bert_score) (4.41.1)
# Requirement already satisfied: numpy in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from bert_score) (1.26.4)
# Requirement already satisfied: requests in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from bert_score) (2.32.5)
# Requirement already satisfied: tqdm>=4.31.1 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from bert_score) (4.67.1)
# Requirement already satisfied: matplotlib in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from bert_score) (3.10.7)
# Requirement already satisfied: packaging>=20.9 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from bert_score) (25.0)
# Requirement already satisfied: regex in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from sacremoses) (2025.11.3)
# Requirement already satisfied: click in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from sacremoses) (8.3.1)
# Requirement already satisfied: joblib in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from sacremoses) (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from pandas>=1.0.1->bert_score) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from pandas>=1.0.1->bert_score) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from pandas>=1.0.1->bert_score) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert_score) (1.17.0)
# Requirement already satisfied: filelock in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (4.15.0)
# Requirement already satisfied: networkx in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (3.1.6)
# Requirement already satisfied: fsspec in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (2023.10.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from sympy==1.13.1->torch>=1.0.0->bert_score) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (0.36.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (6.0.1)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (0.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers>=3.0.0->bert_score) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from jinja2->torch>=1.0.0->bert_score) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from matplotlib->bert_score) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from matplotlib->bert_score) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from matplotlib->bert_score) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from matplotlib->bert_score) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from matplotlib->bert_score) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from requests->bert_score) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from requests->bert_score) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from requests->bert_score) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/machira/projects/cs598/patient_summaries_with_llms/.venv/lib/python3.10/site-packages (from requests->bert_score) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.

# %%
# @title Install dependencies used by both scripts
# %pip install -q transformers==4.39.3 datasets==2.18.0 accelerate==0.28.0 evaluate rouge-score sacrebleu sentencepiece trl==0.7.10 peft==0.10.0 wandb
# Out:
# Found existing installation: peft 0.10.0
# Uninstalling peft-0.10.0:
#   Successfully uninstalled peft-0.10.0
# WARNING: Skipping bitsandbytes as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## LED smoke run (`summarization/run_summarization.py`)
#
# Trains/evaluates `allenai/led-base-16384` on the last 100 training examples for one epoch to ensure that tokenization, dataloading, and Trainer hooks work.

# %%
# # @title LED-base on train_last_100 / valid_last_100
# import os
# from pathlib import Path

# os.environ["WANDB_MODE"] = "offline"
# DATA_DIR = Path("data/ann-pt-summ/1.0.1/mimic-iv-note-ext-di-bhc/dataset")

# assert DATA_DIR.exists(), f"Missing dataset folder: {DATA_DIR}"

#     # --do_train --do_eval --do_predict \
# !python summarization/run_summarization.py \
#     --model_name_or_path data/led_4000_600_chars/ \
#     --test_file {DATA_DIR / 'test_4000_600_chars_last_100.json'} \
#     --text_column text \
#     --summary_column summary \
#     --output_dir results/led_full_run_predict \
#     --do_predict \
#     --predict_with_generate \
#     --per_device_eval_batch_size 1 \
#     --max_source_length 4096 \
#     --max_target_length 350 \
#     --report_to none

# %% [markdown]
# ## Llama LoRA smoke run (`summarization/fine_tune_llama.py`)
#
# Runs a tiny LoRA training job on the same dataset subset (100 examples). This assumes you already have access to `meta-llama/Llama-2-7b-hf` and a GPU runtime; set `HF_TOKEN` in the environment if needed.

# %%
# @title (Optional) Install Llama-specific dependencies
# %pip uninstall -y transformers
# %pip install -r requirements-llama.txt
# Out:
# Found existing installation: transformers 4.38.2
# Uninstalling transformers-4.38.2:
#   Successfully uninstalled transformers-4.38.2
# Requirement already satisfied: peft==0.10.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements-llama.txt (line 1)) (0.10.0)
# Requirement already satisfied: trl==0.7.10 in /usr/local/lib/python3.12/dist-packages (from -r requirements-llama.txt (line 2)) (0.7.10)
# Collecting transformers==4.38.2 (from -r requirements-llama.txt (line 3))
#   Using cached transformers-4.38.2-py3-none-any.whl.metadata (130 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0->-r requirements-llama.txt (line 1)) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0->-r requirements-llama.txt (line 1)) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0->-r requirements-llama.txt (line 1)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0->-r requirements-llama.txt (line 1)) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0->-r requirements-llama.txt (line 1)) (2.6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0->-r requirements-llama.txt (line 1)) (4.67.1)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0->-r requirements-llama.txt (line 1)) (0.28.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0->-r requirements-llama.txt (line 1)) (0.7.0)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.10.0->-r requirements-llama.txt (line 1)) (0.36.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (from trl==0.7.10->-r requirements-llama.txt (line 2)) (2.18.0)
# Requirement already satisfied: tyro>=0.5.11 in /usr/local/lib/python3.12/dist-packages (from trl==0.7.10->-r requirements-llama.txt (line 2)) (0.9.35)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.38.2->-r requirements-llama.txt (line 3)) (3.20.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.38.2->-r requirements-llama.txt (line 3)) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.38.2->-r requirements-llama.txt (line 3)) (2.32.4)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.12/dist-packages (from transformers==4.38.2->-r requirements-llama.txt (line 3)) (0.15.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.17.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.17.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.17.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (1.2.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (3.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (75.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (1.3.0)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.12/dist-packages (from tyro>=0.5.11->trl==0.7.10->-r requirements-llama.txt (line 2)) (0.17.0)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.12/dist-packages (from tyro>=0.5.11->trl==0.7.10->-r requirements-llama.txt (line 2)) (13.9.4)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from tyro>=0.5.11->trl==0.7.10->-r requirements-llama.txt (line 2)) (1.8.0)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from tyro>=0.5.11->trl==0.7.10->-r requirements-llama.txt (line 2)) (4.4.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets->trl==0.7.10->-r requirements-llama.txt (line 2)) (18.1.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.12/dist-packages (from datasets->trl==0.7.10->-r requirements-llama.txt (line 2)) (0.7)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets->trl==0.7.10->-r requirements-llama.txt (line 2)) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets->trl==0.7.10->-r requirements-llama.txt (line 2)) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets->trl==0.7.10->-r requirements-llama.txt (line 2)) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from datasets->trl==0.7.10->-r requirements-llama.txt (line 2)) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from datasets->trl==0.7.10->-r requirements-llama.txt (line 2)) (3.13.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.38.2->-r requirements-llama.txt (line 3)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.38.2->-r requirements-llama.txt (line 3)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.38.2->-r requirements-llama.txt (line 3)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.38.2->-r requirements-llama.txt (line 3)) (2025.11.12)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets->trl==0.7.10->-r requirements-llama.txt (line 2)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets->trl==0.7.10->-r requirements-llama.txt (line 2)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets->trl==0.7.10->-r requirements-llama.txt (line 2)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets->trl==0.7.10->-r requirements-llama.txt (line 2)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets->trl==0.7.10->-r requirements-llama.txt (line 2)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets->trl==0.7.10->-r requirements-llama.txt (line 2)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets->trl==0.7.10->-r requirements-llama.txt (line 2)) (1.22.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.7.10->-r requirements-llama.txt (line 2)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.7.10->-r requirements-llama.txt (line 2)) (2.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->peft==0.10.0->-r requirements-llama.txt (line 1)) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->trl==0.7.10->-r requirements-llama.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->trl==0.7.10->-r requirements-llama.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->trl==0.7.10->-r requirements-llama.txt (line 2)) (2025.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl==0.7.10->-r requirements-llama.txt (line 2)) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->trl==0.7.10->-r requirements-llama.txt (line 2)) (1.17.0)
# Using cached transformers-4.38.2-py3-none-any.whl (8.5 MB)
# Installing collected packages: transformers
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 5.1.2 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.38.2 which is incompatible.
# Successfully installed transformers-4.38.2

# %%
# @title Configure HF token and output directories
import os
from pathlib import Path

HF_TOKEN = ""  # @param {"type": "string"}
if HF_TOKEN:
    os.environ["HF_TOKEN"] = HF_TOKEN
os.environ["WANDB_MODE"] = "offline"

DATA_DIR = Path("data/ann-pt-summ/1.0.1/mimic-iv-note-ext-di-bhc/dataset")
assert DATA_DIR.exists(), f"Missing dataset folder: {DATA_DIR}"

# %%
# %pip uninstall peft
# %pip install peft==0.17.0
# Out:
# Found existing installation: peft 0.10.0
# Uninstalling peft-0.10.0:
#   Would remove:
#     /usr/local/lib/python3.12/dist-packages/peft-0.10.0.dist-info/*
#     /usr/local/lib/python3.12/dist-packages/peft/*
# Proceed (Y/n)? y
#   Successfully uninstalled peft-0.10.0
# Collecting peft==0.17.0
#   Using cached peft-0.17.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from peft==0.17.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.17.0) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft==0.17.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from peft==0.17.0) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.17.0) (2.6.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from peft==0.17.0) (4.38.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from peft==0.17.0) (4.67.1)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.17.0) (0.28.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from peft==0.17.0) (0.7.0)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.17.0) (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft==0.17.0) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft==0.17.0) (2024.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft==0.17.0) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft==0.17.0) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft==0.17.0) (1.2.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (3.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (75.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft==0.17.0) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->peft==0.17.0) (2025.11.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.12/dist-packages (from transformers->peft==0.17.0) (0.15.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->peft==0.17.0) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.25.0->peft==0.17.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.25.0->peft==0.17.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.25.0->peft==0.17.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.25.0->peft==0.17.0) (2025.11.12)
# Using cached peft-0.17.0-py3-none-any.whl (503 kB)
# Installing collected packages: peft
# Successfully installed peft-0.17.0

# %%
# @title Llama 2 7B LoRA fine-tuning on 100-example subset
# !python summarization/fine_tune_llama.py \
    --model_name_or_path meta-llama/Llama-2-7b-hf \
    --data_path {DATA_DIR} \
    --output_path results/llama_full_run_predict \
    --evaluation \
    --evaluation_model_path data/llama_4000_600_chars/best_val_loss \
    --num_test_examples 100
# Out:
# Traceback (most recent call last):
#   File "/content/patient_summaries_with_llms/summarization/fine_tune_llama.py", line 10, in <module>
#     from peft import (
#   File "/usr/local/lib/python3.12/dist-packages/peft/__init__.py", line 17, in <module>
#     from .auto import (
#   File "/usr/local/lib/python3.12/dist-packages/peft/auto.py", line 31, in <module>
#     from .config import PeftConfig
#   File "/usr/local/lib/python3.12/dist-packages/peft/config.py", line 24, in <module>
#     from .utils import CONFIG_NAME, PeftType, TaskType
#   File "/usr/local/lib/python3.12/dist-packages/peft/utils/__init__.py", line 16, in <module>
#     from .loftq_utils import replace_lora_weights_loftq
#   File "/usr/local/lib/python3.12/dist-packages/peft/utils/loftq_utils.py", line 25, in <module>
#     from accelerate.utils.memory import clear_device_cache
# ImportError: cannot import name 'clear_device_cache' from 'accelerate.utils.memory' (/usr/local/lib/python3.12/dist-packages/accelerate/utils/memory.py)

# %%
# %pip show accelerate
# Out:
# Name: accelerate
# Version: 0.28.0
# Summary: Accelerate
# Home-page: https://github.com/huggingface/accelerate
# Author: The HuggingFace team
# Author-email: zach.mueller@huggingface.co
# License: Apache
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: huggingface-hub, numpy, packaging, psutil, pyyaml, safetensors, torch
# Required-by: peft, trl

# %%
# %pip show peft
# Out:
# Name: peft
# Version: 0.17.0
# Summary: Parameter-Efficient Fine-Tuning (PEFT)
# Home-page: https://github.com/huggingface/peft
# Author: The HuggingFace team
# Author-email: benjamin@huggingface.co
# License: Apache
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: accelerate, huggingface_hub, numpy, packaging, psutil, pyyaml, safetensors, torch, tqdm, transformers
# Required-by:

# %%
import peft
print("accelerate", accelerate.__version__, accelerate.__file__)
# print("peft", peft.__version__, peft.__file__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-2423276112.py in <cell line: 0>()
# ----> 1 import peft
#       2 print("accelerate", accelerate.__version__, accelerate.__file__)
#       3 # print("peft", peft.__version__, peft.__file__)
#
# /usr/local/lib/python3.12/dist-packages/peft/__init__.py in <module>
#      15 __version__ = "0.17.0"
#      16
# ---> 17 from .auto import (
#      18     MODEL_TYPE_TO_PEFT_MODEL_MAPPING,
#      19     AutoPeftModel,
#
# /usr/local/lib/python3.12/dist-packages/peft/auto.py in <module>
#      29 )
#      30
# ---> 31 from .config import PeftConfig
#      32 from .peft_model import (
#      33     PeftModel,
#
# /usr/local/lib/python3.12/dist-packages/peft/config.py in <module>
#      22 from transformers.utils import PushToHubMixin, http_user_agent
#      23
# ---> 24 from .utils import CONFIG_NAME, PeftType, TaskType
#      25
#      26
#
# /usr/local/lib/python3.12/dist-packages/peft/utils/__init__.py in <module>
#      14
#      15 from .integrations import map_cache_to_layer_device_map
# ---> 16 from .loftq_utils import replace_lora_weights_loftq
#      17 from .other import (
#      18     CONFIG_NAME,
#
# /usr/local/lib/python3.12/dist-packages/peft/utils/loftq_utils.py in <module>
#      23
#      24 import torch
# ---> 25 from accelerate.utils.memory import clear_device_cache
#      26 from huggingface_hub import snapshot_download
#      27 from huggingface_hub.errors import HFValidationError, LocalEntryNotFoundError
#
# ImportError: cannot import name 'clear_device_cache' from 'accelerate.utils.memory' (/usr/local/lib/python3.12/dist-packages/accelerate/utils/memory.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
