# %% [markdown]
# # Paper Reproduction Launcher (Smoke Run)
#
# This Colab-friendly notebook drives the existing CLI scripts in `summarization/` to run very small LED and Llama jobs. It uses the `train_last_100.json` / `valid_last_100.json` splits so we can exercise the full code paths quickly before launching the long runs described in the paper.

# %%
# @title Sync the local repository from Google Drive (no git clone)
from pathlib import Path
import os
import importlib.util

COLAB = importlib.util.find_spec("google.colab") is not None
if COLAB:
    from google.colab import drive  # type: ignore
    drive.mount('/content/drive', force_remount=True)
    REPO_IN_DRIVE = Path('/content/drive/Othercomputers/My Mac/patient_summaries_with_llms/')  # @param {type:"string"}
    if not REPO_IN_DRIVE.exists():
        raise FileNotFoundError(f"Upload/sync the local repo to {REPO_IN_DRIVE} first.")
    TARGET_DIR = Path('/content/patient_summaries_with_llms')
    TARGET_DIR.mkdir(parents=True, exist_ok=True)
    os.system(f"rsync --progress -a --delete '{REPO_IN_DRIVE}/summarization' '{TARGET_DIR}/'")
    os.system(f"rsync --progress -a --delete '{REPO_IN_DRIVE}/data' '{TARGET_DIR}/'")
    os.system(f"rsync --progress -a --delete '{REPO_IN_DRIVE}/requirements.txt' '{TARGET_DIR}/'")
    # %cd /content/patient_summaries_with_llms
else:
    print("Running outside Colab; using the current working directory.")
    TARGET_DIR = Path.cwd()
# Out:
# Mounted at /content/drive
# /content/patient_summaries_with_llms

# %%
# @title Install base dependencies shared by LED + evaluation
# %pip install -q -r requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 52.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.6/766.6 MB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 58.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 49.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 44.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 63.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.3/106.3 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 44.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 725.0/725.0 kB 32.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 71.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 55.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 64.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 93.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 MB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 41.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 80.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 9.3 MB/s eta 0:00:00
#   Building wheel for sentencepiece (setup.py) ... done
#   Building wheel for bert (setup.py) ... done
#   Building wheel for erlastic (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.8 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opentelemetry-proto 1.37.0 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.8 which is incompatible.
# sentence-transformers 5.1.2 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.40.1 which is incompatible.
# google-adk 1.19.0 requires PyYAML<7.0.0,>=6.0.2, but you have pyyaml 6.0.1 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.8 which is incompatible.
# pytensor 2.35.1 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.

# %%
# @title Install dependencies used by both scripts
# %pip install -q transformers==4.39.3 datasets==2.18.0 accelerate==0.28.0 evaluate rouge-score sacrebleu sentencepiece trl==0.7.10 peft==0.10.0 wandb
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 5.1.2 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.39.3 which is incompatible.

# %% [markdown]
# ## LED smoke run (`summarization/run_summarization.py`)
#
# Trains/evaluates `allenai/led-base-16384` on the last 100 training examples for one epoch to ensure that tokenization, dataloading, and Trainer hooks work.

# %%
# # @title LED-base on train_last_100 / valid_last_100
# import os
# from pathlib import Path

# os.environ["WANDB_MODE"] = "offline"
# DATA_DIR = Path("data/ann-pt-summ/1.0.1/mimic-iv-note-ext-di-bhc/dataset")

# assert DATA_DIR.exists(), f"Missing dataset folder: {DATA_DIR}"

#     # --do_train --do_eval --do_predict \
# !python summarization/run_summarization.py \
#     --model_name_or_path data/led_4000_600_chars/ \
#     --test_file {DATA_DIR / 'test_4000_600_chars_last_100.json'} \
#     --text_column text \
#     --summary_column summary \
#     --output_dir results/led_full_run_predict \
#     --do_predict \
#     --predict_with_generate \
#     --per_device_eval_batch_size 1 \
#     --max_source_length 4096 \
#     --max_target_length 350 \
#     --report_to none
# Out:
# 2025-12-06 03:21:40.193622: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764991300.447639    4735 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764991300.524329    4735 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764991301.050985    4735 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764991301.051048    4735 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764991301.051053    4735 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764991301.051058    4735 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# wandb: Tracking run with wandb version 0.16.6
# wandb: W&B syncing is set to `offline` in this directory.
# wandb: Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# 12/06/2025 03:21:52 - WARNING - __main__ -   Process rank: 0, device: cpu, n_gpu: 0distributed training: True, 16-bits training: False
# 12/06/2025 03:21:52 - INFO - __main__ -   Training/evaluation parameters Seq2SeqTrainingArguments(
# _n_gpu=0,
# accelerator_config={'split_batches': False, 'dispatch_batches': None, 'even_batches': True, 'use_seedable_sampler': True},
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_persistent_workers=False,
# dataloader_pin_memory=True,
# dataloader_prefetch_factor=None,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# dispatch_batches=None,
# do_eval=False,
# do_predict=True,
# do_train=False,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=None,
# evaluation_strategy=IntervalStrategy.NO,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_v2': False, 'xla_fsdp_grad_ckpt': False},
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# generation_config=None,
# generation_max_length=None,
# generation_num_beams=None,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# gradient_checkpointing_kwargs=None,
# greater_is_better=None,
# group_by_length=False,
# half_precision_backend=auto,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=False,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_inputs_for_metrics=False,
# include_num_input_tokens_seen=False,
# include_tokens_per_second=False,
# jit_mode_eval=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=5e-05,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=0,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=results/led_full_run_predict/runs/Dec06_03-21-50_24523cd22264,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=500,
# logging_strategy=IntervalStrategy.STEPS,
# lr_scheduler_kwargs={},
# lr_scheduler_type=SchedulerType.LINEAR,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=None,
# mp_parameters=,
# neftune_noise_alpha=None,
# no_cuda=False,
# num_train_epochs=3.0,
# optim=OptimizerNames.ADAMW_TORCH,
# optim_args=None,
# optim_target_modules=None,
# output_dir=results/led_full_run_predict,
# overwrite_output_dir=False,
# past_index=-1,
# per_device_eval_batch_size=1,
# per_device_train_batch_size=8,
# predict_with_generate=True,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# ray_scope=last,
# remove_unused_columns=True,
# report_to=['wandb'],
# resume_from_checkpoint=None,
# run_name=results/led_full_run_predict,
# save_on_each_node=False,
# save_only_model=False,
# save_safetensors=True,
# save_steps=500,
# save_strategy=IntervalStrategy.STEPS,
# save_total_limit=None,
# seed=42,
# skip_memory_metrics=True,
# sortish_sampler=False,
# split_batches=None,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torchdynamo=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_cpu=False,
# use_ipex=False,
# use_legacy_prediction_loop=False,
# use_mps_device=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.0,
# )
# Generating test split: 100 examples [00:00, 2579.03 examples/s]
# loading configuration file data/led_4000_600_chars/config.json
# Model config LEDConfig {
#   "_name_or_path": "data/led_4000_600_chars/",
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "architectures": [
#     "LEDForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "attention_window": [
#     1024,
#     1024,
#     1024,
#     1024,
#     1024,
#     1024
#   ],
#   "bos_token_id": 0,
#   "classif_dropout": 0.0,
#   "classifier_dropout": 0.0,
#   "d_model": 768,
#   "decoder_attention_heads": 12,
#   "decoder_ffn_dim": 3072,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 2,
#   "dropout": 0.1,
#   "encoder_attention_heads": 12,
#   "encoder_ffn_dim": 3072,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 6,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "max_decoder_position_embeddings": 1024,
#   "max_encoder_position_embeddings": 16384,
#   "model_type": "led",
#   "num_hidden_layers": 6,
#   "pad_token_id": 1,
#   "torch_dtype": "float32",
#   "transformers_version": "4.39.3",
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading file vocab.json
# loading file merges.txt
# loading file tokenizer.json
# loading file added_tokens.json
# loading file special_tokens_map.json
# loading file tokenizer_config.json
# loading weights file data/led_4000_600_chars/model.safetensors
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "eos_token_id": 2,
#   "pad_token_id": 1
# }
#
# All model checkpoint weights were used when initializing LEDForConditionalGeneration.
#
# All the weights of LEDForConditionalGeneration were initialized from the model checkpoint at data/led_4000_600_chars/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use LEDForConditionalGeneration for predictions without further training.
# loading configuration file data/led_4000_600_chars/generation_config.json
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "eos_token_id": 2,
#   "pad_token_id": 1
# }
#
# Map:   0% 0/100 [00:00<?, ? examples/s]/usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:3935: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map: 100% 100/100 [00:00<00:00, 364.18 examples/s]
# Downloading builder script: 6.14kB [00:00, 8.10MB/s]
# /usr/local/lib/python3.12/dist-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
# 12/06/2025 03:21:57 - INFO - __main__ -   *** Test ***
# ***** Running Prediction *****
#   Num examples = 100
#   Batch size = 1
# Input ids are automatically padded from 331 to 1024 to be a multiple of `config.attention_window`: 1024
#   0% 0/100 [00:00<?, ?it/s]Input ids are automatically padded from 421 to 1024 to be a multiple of `config.attention_window`: 1024
#   2% 2/100 [00:15<12:55,  7.91s/it]Input ids are automatically padded from 254 to 1024 to be a multiple of `config.attention_window`: 1024
#   3% 3/100 [00:31<18:08, 11.22s/it]Input ids are automatically padded from 597 to 1024 to be a multiple of `config.attention_window`: 1024
#   4% 4/100 [00:49<21:58, 13.74s/it]Input ids are automatically padded from 399 to 1024 to be a multiple of `config.attention_window`: 1024
#   5% 5/100 [01:07<23:59, 15.15s/it]Input ids are automatically padded from 369 to 1024 to be a multiple of `config.attention_window`: 1024
#   6% 6/100 [01:22<23:51, 15.23s/it]Input ids are automatically padded from 773 to 1024 to be a multiple of `config.attention_window`: 1024
#   7% 7/100 [01:39<24:15, 15.65s/it]Input ids are automatically padded from 538 to 1024 to be a multiple of `config.attention_window`: 1024
#   8% 8/100 [01:57<25:06, 16.37s/it]Input ids are automatically padded from 874 to 1024 to be a multiple of `config.attention_window`: 1024
#   9% 9/100 [02:14<25:24, 16.76s/it]Input ids are automatically padded from 354 to 1024 to be a multiple of `config.attention_window`: 1024
#  10% 10/100 [02:31<25:16, 16.85s/it]Input ids are automatically padded from 741 to 1024 to be a multiple of `config.attention_window`: 1024
#  11% 11/100 [02:48<24:52, 16.77s/it]Input ids are automatically padded from 812 to 1024 to be a multiple of `config.attention_window`: 1024
#  12% 12/100 [03:05<24:30, 16.71s/it]Input ids are automatically padded from 617 to 1024 to be a multiple of `config.attention_window`: 1024
#  13% 13/100 [03:21<24:09, 16.66s/it]Input ids are automatically padded from 390 to 1024 to be a multiple of `config.attention_window`: 1024
#  14% 14/100 [03:39<24:13, 16.90s/it]Input ids are automatically padded from 855 to 1024 to be a multiple of `config.attention_window`: 1024
#  15% 15/100 [04:05<28:06, 19.84s/it]Input ids are automatically padded from 416 to 1024 to be a multiple of `config.attention_window`: 1024
#  16% 16/100 [04:26<28:13, 20.16s/it]Input ids are automatically padded from 119 to 1024 to be a multiple of `config.attention_window`: 1024
#  17% 17/100 [04:42<26:13, 18.96s/it]Input ids are automatically padded from 675 to 1024 to be a multiple of `config.attention_window`: 1024
#  18% 18/100 [04:59<24:48, 18.16s/it]Input ids are automatically padded from 722 to 1024 to be a multiple of `config.attention_window`: 1024
#  19% 19/100 [05:16<23:59, 17.78s/it]Input ids are automatically padded from 576 to 1024 to be a multiple of `config.attention_window`: 1024
#  20% 20/100 [05:34<24:00, 18.01s/it]Input ids are automatically padded from 672 to 1024 to be a multiple of `config.attention_window`: 1024
#  21% 21/100 [05:51<23:20, 17.73s/it]Input ids are automatically padded from 945 to 1024 to be a multiple of `config.attention_window`: 1024
#  22% 22/100 [06:08<22:45, 17.51s/it]Input ids are automatically padded from 501 to 1024 to be a multiple of `config.attention_window`: 1024
#  23% 23/100 [06:24<21:42, 16.91s/it]Input ids are automatically padded from 643 to 1024 to be a multiple of `config.attention_window`: 1024
#  24% 24/100 [06:41<21:25, 16.92s/it]Input ids are automatically padded from 375 to 1024 to be a multiple of `config.attention_window`: 1024
#  25% 25/100 [06:58<21:29, 17.19s/it]Input ids are automatically padded from 445 to 1024 to be a multiple of `config.attention_window`: 1024
#  26% 26/100 [07:14<20:43, 16.80s/it]Input ids are automatically padded from 665 to 1024 to be a multiple of `config.attention_window`: 1024
#  27% 27/100 [07:31<20:17, 16.68s/it]Input ids are automatically padded from 453 to 1024 to be a multiple of `config.attention_window`: 1024
#  28% 28/100 [07:51<21:21, 17.79s/it]Input ids are automatically padded from 856 to 1024 to be a multiple of `config.attention_window`: 1024
#  29% 29/100 [08:10<21:28, 18.15s/it]Input ids are automatically padded from 699 to 1024 to be a multiple of `config.attention_window`: 1024
#  30% 30/100 [08:38<24:33, 21.05s/it]Input ids are automatically padded from 952 to 1024 to be a multiple of `config.attention_window`: 1024
#  31% 31/100 [08:56<23:03, 20.05s/it]Input ids are automatically padded from 289 to 1024 to be a multiple of `config.attention_window`: 1024
#  32% 32/100 [09:12<21:17, 18.79s/it]Input ids are automatically padded from 884 to 1024 to be a multiple of `config.attention_window`: 1024
#  34% 34/100 [09:45<19:34, 17.80s/it]Input ids are automatically padded from 498 to 1024 to be a multiple of `config.attention_window`: 1024
#  35% 35/100 [10:02<18:56, 17.48s/it]Input ids are automatically padded from 795 to 1024 to be a multiple of `config.attention_window`: 1024
#  36% 36/100 [10:19<18:24, 17.26s/it]Input ids are automatically padded from 743 to 1024 to be a multiple of `config.attention_window`: 1024
#  37% 37/100 [10:34<17:36, 16.77s/it]Input ids are automatically padded from 512 to 1024 to be a multiple of `config.attention_window`: 1024
#  38% 38/100 [10:52<17:32, 16.98s/it]Input ids are automatically padded from 739 to 1024 to be a multiple of `config.attention_window`: 1024
#  39% 39/100 [11:09<17:25, 17.14s/it]Input ids are automatically padded from 401 to 1024 to be a multiple of `config.attention_window`: 1024
#  40% 40/100 [11:26<17:00, 17.01s/it]Input ids are automatically padded from 568 to 1024 to be a multiple of `config.attention_window`: 1024
#  42% 42/100 [12:00<16:27, 17.03s/it]Input ids are automatically padded from 524 to 1024 to be a multiple of `config.attention_window`: 1024
#  43% 43/100 [12:17<16:11, 17.04s/it]Input ids are automatically padded from 431 to 1024 to be a multiple of `config.attention_window`: 1024
#  44% 44/100 [12:33<15:34, 16.68s/it]Input ids are automatically padded from 589 to 1024 to be a multiple of `config.attention_window`: 1024
#  45% 45/100 [12:49<15:04, 16.44s/it]Input ids are automatically padded from 406 to 1024 to be a multiple of `config.attention_window`: 1024
#  46% 46/100 [13:05<14:39, 16.28s/it]Input ids are automatically padded from 970 to 1024 to be a multiple of `config.attention_window`: 1024
#  47% 47/100 [13:23<14:59, 16.97s/it]Input ids are automatically padded from 458 to 1024 to be a multiple of `config.attention_window`: 1024
#  48% 48/100 [13:50<17:10, 19.82s/it]Input ids are automatically padded from 604 to 1024 to be a multiple of `config.attention_window`: 1024
#  49% 49/100 [14:20<19:29, 22.92s/it]Input ids are automatically padded from 529 to 1024 to be a multiple of `config.attention_window`: 1024
#  50% 50/100 [14:35<17:12, 20.65s/it]Input ids are automatically padded from 825 to 1024 to be a multiple of `config.attention_window`: 1024
#  51% 51/100 [14:51<15:42, 19.24s/it]Input ids are automatically padded from 738 to 1024 to be a multiple of `config.attention_window`: 1024
#  52% 52/100 [15:07<14:36, 18.25s/it]Input ids are automatically padded from 345 to 1024 to be a multiple of `config.attention_window`: 1024
#  53% 53/100 [15:24<13:50, 17.66s/it]Input ids are automatically padded from 563 to 1024 to be a multiple of `config.attention_window`: 1024
#  54% 54/100 [15:41<13:24, 17.49s/it]Input ids are automatically padded from 575 to 1024 to be a multiple of `config.attention_window`: 1024
#  56% 56/100 [16:12<12:13, 16.67s/it]Input ids are automatically padded from 852 to 1024 to be a multiple of `config.attention_window`: 1024
#  57% 57/100 [16:29<11:58, 16.70s/it]Input ids are automatically padded from 419 to 1024 to be a multiple of `config.attention_window`: 1024
#  58% 58/100 [16:46<11:44, 16.78s/it]Input ids are automatically padded from 794 to 1024 to be a multiple of `config.attention_window`: 1024
#  59% 59/100 [17:02<11:21, 16.63s/it]Input ids are automatically padded from 305 to 1024 to be a multiple of `config.attention_window`: 1024
#  60% 60/100 [17:19<11:02, 16.57s/it]Input ids are automatically padded from 500 to 1024 to be a multiple of `config.attention_window`: 1024
#  61% 61/100 [17:35<10:42, 16.47s/it]Input ids are automatically padded from 450 to 1024 to be a multiple of `config.attention_window`: 1024
#  62% 62/100 [17:51<10:24, 16.44s/it]Input ids are automatically padded from 637 to 1024 to be a multiple of `config.attention_window`: 1024
#  63% 63/100 [18:09<10:23, 16.86s/it]Input ids are automatically padded from 224 to 1024 to be a multiple of `config.attention_window`: 1024
#  64% 64/100 [18:26<10:02, 16.73s/it]Input ids are automatically padded from 341 to 1024 to be a multiple of `config.attention_window`: 1024
#  65% 65/100 [18:40<09:25, 16.15s/it]Input ids are automatically padded from 811 to 1024 to be a multiple of `config.attention_window`: 1024
#  67% 67/100 [19:14<09:09, 16.65s/it]Input ids are automatically padded from 544 to 1024 to be a multiple of `config.attention_window`: 1024
#  68% 68/100 [19:31<08:55, 16.74s/it]Input ids are automatically padded from 465 to 1024 to be a multiple of `config.attention_window`: 1024
#  69% 69/100 [19:47<08:34, 16.58s/it]Input ids are automatically padded from 466 to 1024 to be a multiple of `config.attention_window`: 1024
#  70% 70/100 [20:03<08:06, 16.21s/it]Input ids are automatically padded from 442 to 1024 to be a multiple of `config.attention_window`: 1024
#  72% 72/100 [20:35<07:32, 16.17s/it]Input ids are automatically padded from 207 to 1024 to be a multiple of `config.attention_window`: 1024
#  73% 73/100 [20:53<07:37, 16.96s/it]Input ids are automatically padded from 960 to 1024 to be a multiple of `config.attention_window`: 1024
#  74% 74/100 [21:10<07:18, 16.87s/it]Input ids are automatically padded from 914 to 1024 to be a multiple of `config.attention_window`: 1024
#  75% 75/100 [21:27<07:02, 16.90s/it]Input ids are automatically padded from 930 to 1024 to be a multiple of `config.attention_window`: 1024
#  76% 76/100 [21:44<06:47, 16.99s/it]Input ids are automatically padded from 769 to 1024 to be a multiple of `config.attention_window`: 1024
#  77% 77/100 [22:02<06:38, 17.34s/it]Input ids are automatically padded from 754 to 1024 to be a multiple of `config.attention_window`: 1024
#  78% 78/100 [22:19<06:13, 16.97s/it]Input ids are automatically padded from 955 to 1024 to be a multiple of `config.attention_window`: 1024
#  79% 79/100 [22:35<05:51, 16.71s/it]Input ids are automatically padded from 264 to 1024 to be a multiple of `config.attention_window`: 1024
#  80% 80/100 [22:51<05:31, 16.57s/it]Input ids are automatically padded from 608 to 1024 to be a multiple of `config.attention_window`: 1024
#  81% 81/100 [23:10<05:26, 17.21s/it]Input ids are automatically padded from 340 to 1024 to be a multiple of `config.attention_window`: 1024
#  82% 82/100 [23:26<05:04, 16.92s/it]Input ids are automatically padded from 661 to 1024 to be a multiple of `config.attention_window`: 1024
#  83% 83/100 [23:42<04:42, 16.65s/it]Input ids are automatically padded from 295 to 1024 to be a multiple of `config.attention_window`: 1024
#  84% 84/100 [23:58<04:23, 16.48s/it]Input ids are automatically padded from 981 to 1024 to be a multiple of `config.attention_window`: 1024
#  85% 85/100 [24:20<04:30, 18.06s/it]Input ids are automatically padded from 503 to 1024 to be a multiple of `config.attention_window`: 1024
#  86% 86/100 [24:35<04:01, 17.26s/it]Input ids are automatically padded from 217 to 1024 to be a multiple of `config.attention_window`: 1024
#  87% 87/100 [24:52<03:43, 17.23s/it]Input ids are automatically padded from 590 to 1024 to be a multiple of `config.attention_window`: 1024
#  88% 88/100 [25:08<03:20, 16.67s/it]Input ids are automatically padded from 438 to 1024 to be a multiple of `config.attention_window`: 1024
#  89% 89/100 [25:25<03:04, 16.82s/it]Input ids are automatically padded from 277 to 1024 to be a multiple of `config.attention_window`: 1024
#  90% 90/100 [25:42<02:48, 16.81s/it]Input ids are automatically padded from 664 to 1024 to be a multiple of `config.attention_window`: 1024
#  91% 91/100 [25:59<02:31, 16.89s/it]Input ids are automatically padded from 267 to 1024 to be a multiple of `config.attention_window`: 1024
#  92% 92/100 [26:14<02:11, 16.44s/it]Input ids are automatically padded from 489 to 1024 to be a multiple of `config.attention_window`: 1024
#  93% 93/100 [26:32<01:58, 16.86s/it]Input ids are automatically padded from 352 to 1024 to be a multiple of `config.attention_window`: 1024
#  94% 94/100 [26:49<01:40, 16.83s/it]Input ids are automatically padded from 531 to 1024 to be a multiple of `config.attention_window`: 1024
#  95% 95/100 [27:05<01:23, 16.67s/it]Input ids are automatically padded from 641 to 1024 to be a multiple of `config.attention_window`: 1024
#  96% 96/100 [27:21<01:06, 16.64s/it]Input ids are automatically padded from 707 to 1024 to be a multiple of `config.attention_window`: 1024
#  97% 97/100 [27:44<00:55, 18.51s/it]Input ids are automatically padded from 367 to 1024 to be a multiple of `config.attention_window`: 1024
#  98% 98/100 [28:00<00:35, 17.64s/it]Input ids are automatically padded from 983 to 1024 to be a multiple of `config.attention_window`: 1024
# 100% 100/100 [28:34<00:00, 17.15s/it]
# ***** test metrics *****
#   test_gen_len            =     145.79
#   test_loss               =     1.8646
#   test_rouge1             =      43.21
#   test_rouge2             =    15.9021
#   test_rougeL             =    27.5519
#   test_rougeLsum          =    40.4693
#   test_runtime            = 0:28:50.94
#   test_samples            =        100
#   test_samples_per_second =      0.058
#   test_steps_per_second   =      0.058
# Downloading builder script: 7.95kB [00:00, 6.85MB/s]
# Downloading builder script: 12.1kB [00:00, 14.1MB/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 72.1kB/s]
# config.json: 100% 482/482 [00:00<00:00, 1.45MB/s]
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--roberta-large/snapshots/722cf37b1afa9454edce342e7895e588b6ff1d59/config.json
# Model config RobertaConfig {
#   "_name_or_path": "roberta-large",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.39.3",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# vocab.json: 100% 899k/899k [00:00<00:00, 4.72MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 7.64MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 5.45MB/s]
# loading file vocab.json from cache at /root/.cache/huggingface/hub/models--roberta-large/snapshots/722cf37b1afa9454edce342e7895e588b6ff1d59/vocab.json
# loading file merges.txt from cache at /root/.cache/huggingface/hub/models--roberta-large/snapshots/722cf37b1afa9454edce342e7895e588b6ff1d59/merges.txt
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--roberta-large/snapshots/722cf37b1afa9454edce342e7895e588b6ff1d59/tokenizer_config.json
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--roberta-large/snapshots/722cf37b1afa9454edce342e7895e588b6ff1d59/tokenizer.json
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--roberta-large/snapshots/722cf37b1afa9454edce342e7895e588b6ff1d59/config.json
# Model config RobertaConfig {
#   "_name_or_path": "roberta-large",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.39.3",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--roberta-large/snapshots/722cf37b1afa9454edce342e7895e588b6ff1d59/config.json
# Model config RobertaConfig {
#   "_name_or_path": "roberta-large",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.39.3",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# model.safetensors: 100% 1.42G/1.42G [00:25<00:00, 56.2MB/s]
# loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--roberta-large/snapshots/722cf37b1afa9454edce342e7895e588b6ff1d59/model.safetensors
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Traceback (most recent call last):
#   File "/content/patient_summaries_with_llms/summarization/run_summarization.py", line 694, in <module>
#     main()
#   File "/content/patient_summaries_with_llms/summarization/run_summarization.py", line 668, in main
#     metrics_test = compute_custom_metrics(orig_test_dataset[text_column], orig_test_dataset[summary_column], test_preds, 'cuda')
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/patient_summaries_with_llms/summarization/metrics_utils.py", line 30, in compute_custom_metrics
#     bertscore.compute(predictions=preds, references=golds, lang="en", device=device)["f1"]
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/evaluate/module.py", line 462, in compute
#     output = self._compute(**inputs, **compute_kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore/cf4907b18f8f741f202232c0f8009a3bd49ff98802c245abcb6ea51a37a8c05b/bertscore.py", line 189, in _compute
#     self.cached_bertscorer = scorer(
#                              ^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/bert_score/scorer.py", line 99, in __init__
#     self._model.to(self.device)
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 2576, in to
#     return super().to(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1343, in to
#     return self._apply(convert)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 903, in _apply
#     module._apply(fn)
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 903, in _apply
#     module._apply(fn)
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 930, in _apply
#     param_applied = fn(param)
#                     ^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1329, in convert
#     return t.to(
#            ^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 319, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
# wandb: You can sync this run to the cloud by running:
# wandb: wandb sync /content/patient_summaries_with_llms/wandb/offline-run-20251206_032151-47l8ug4e
# wandb: Find logs at: ./wandb/offline-run-20251206_032151-47l8ug4e/logs

# %% [markdown]
# ## Llama LoRA smoke run (`summarization/fine_tune_llama.py`)
#
# Runs a tiny LoRA training job on the same dataset subset (100 examples). This assumes you already have access to `meta-llama/Llama-2-7b-hf` and a GPU runtime; set `HF_TOKEN` in the environment if needed.

# %%
# @title (Optional) Install Llama-specific dependencies
# %pip install -q peft==0.10.0 trl==0.7.10
peft>=0.17.0

# %%
# @title Configure HF token and output directories
import os
from pathlib import Path

HF_TOKEN = ""  # @param {"type": "string"}
if HF_TOKEN:
    os.environ["HF_TOKEN"] = HF_TOKEN
os.environ["WANDB_MODE"] = "offline"

DATA_DIR = Path("data/ann-pt-summ/1.0.1/mimic-iv-note-ext-di-bhc/dataset")
assert DATA_DIR.exists(), f"Missing dataset folder: {DATA_DIR}"

# %%
# %pip uninstall -y transformers>4.38.2
# %pip install transformers==4.38.2
# Out:
# Found existing installation: transformers 4.39.3
# Uninstalling transformers-4.39.3:
#   Successfully uninstalled transformers-4.39.3
# Collecting transformers==4.38.2
#   Downloading transformers-4.38.2-py3-none-any.whl.metadata (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.7/130.7 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.38.2) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.12/dist-packages (from transformers==4.38.2) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.38.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.38.2) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.38.2) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.38.2) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.38.2) (2.32.4)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.12/dist-packages (from transformers==4.38.2) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.38.2) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.38.2) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.38.2) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.38.2) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.38.2) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.38.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.38.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.38.2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.38.2) (2025.11.12)
# Downloading transformers-4.38.2-py3-none-any.whl (8.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 30.1 MB/s eta 0:00:00
# Installing collected packages: transformers
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 5.1.2 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.38.2 which is incompatible.
# Successfully installed transformers-4.38.2

# %%
# %pip uninstall peftY

# %pip install peft==0.17.0
# Out:
# Found existing installation: peft 0.10.0
# Uninstalling peft-0.10.0:
#   Would remove:
#     /usr/local/lib/python3.12/dist-packages/peft-0.10.0.dist-info/*
#     /usr/local/lib/python3.12/dist-packages/peft/*
# Proceed (Y/n)? y
#   Successfully uninstalled peft-0.10.0
# Collecting peft==0.17.0
#   Downloading peft-0.17.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from peft==0.17.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.17.0) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft==0.17.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from peft==0.17.0) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.17.0) (2.6.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from peft==0.17.0) (4.38.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from peft==0.17.0) (4.67.1)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.17.0) (0.28.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from peft==0.17.0) (0.7.0)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.17.0) (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft==0.17.0) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft==0.17.0) (2024.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft==0.17.0) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft==0.17.0) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft==0.17.0) (1.2.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (3.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (75.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.17.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft==0.17.0) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->peft==0.17.0) (2025.11.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.12/dist-packages (from transformers->peft==0.17.0) (0.15.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->peft==0.17.0) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.25.0->peft==0.17.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.25.0->peft==0.17.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.25.0->peft==0.17.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.25.0->peft==0.17.0) (2025.11.12)
# Downloading peft-0.17.0-py3-none-any.whl (503 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.9/503.9 kB 11.0 MB/s eta 0:00:00
# Installing collected packages: peft
# Successfully installed peft-0.17.0

# %%
# @title Llama 2 7B LoRA fine-tuning on 100-example subset
# !python summarization/fine_tune_llama.py \
    --model_name_or_path meta-llama/Llama-2-7b-hf \
    --data_path {DATA_DIR} \
    --output_path results/llama_full_run_predict \
    --evaluation \
    --evaluation_model_path data/llama_4000_600_chars/best_val_loss \
    --num_test_examples 100
# Out:
# Traceback (most recent call last):
#   File "/content/patient_summaries_with_llms/summarization/fine_tune_llama.py", line 10, in <module>
#     from peft import (
#   File "/usr/local/lib/python3.12/dist-packages/peft/__init__.py", line 17, in <module>
#     from .auto import (
#   File "/usr/local/lib/python3.12/dist-packages/peft/auto.py", line 31, in <module>
#     from .config import PeftConfig
#   File "/usr/local/lib/python3.12/dist-packages/peft/config.py", line 24, in <module>
#     from .utils import CONFIG_NAME, PeftType, TaskType
#   File "/usr/local/lib/python3.12/dist-packages/peft/utils/__init__.py", line 16, in <module>
#     from .loftq_utils import replace_lora_weights_loftq
#   File "/usr/local/lib/python3.12/dist-packages/peft/utils/loftq_utils.py", line 25, in <module>
#     from accelerate.utils.memory import clear_device_cache
# ImportError: cannot import name 'clear_device_cache' from 'accelerate.utils.memory' (/usr/local/lib/python3.12/dist-packages/accelerate/utils/memory.py)

# %%
# %pip show accelerate
# Out:
# Name: accelerate
# Version: 0.28.0
# Summary: Accelerate
# Home-page: https://github.com/huggingface/accelerate
# Author: The HuggingFace team
# Author-email: zach.mueller@huggingface.co
# License: Apache
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: huggingface-hub, numpy, packaging, psutil, pyyaml, safetensors, torch
# Required-by: peft, trl
